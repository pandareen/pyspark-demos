# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder\
                    .master("local")\
                    .appName('Firstprogram')\
                    .getOrCreate()
sc=spark.sparkContext

# %%
text_file = sc.textFile("wikisent2.txt")
counts = text_file.flatMap(lambda line: line.split(" ")) \
                            .map(lambda word: (word, 1)) \
                           .reduceByKey(lambda x, y: x + y)

# %%
counts.collect()
# Out:
# [('and', 4503808),
#  ('agent', 6227),
#  ('Bond.', 219),
#  ('fourth', 27266),
#  ('this', 146202),
#  ('April', 83848),
#  ('require', 4915),
#  ('these', 45795),
#  ('01:59PM', 1),
#  ('Romford', 95),
#  ('used', 142264),
#  ('(N.D.', 7),
#  ('medical', 18226),
#  ('dealer', 789),
#  ('Kim', 4553),
#  ('born.', 369),
#  ('cassette', 1285),
#  ('corpus', 527),
#  ("Isis's", 9),
#  ('termer', 1),
#  ('type', 26706),
#  ('locomotive.', 411),
#  ('chapters.', 281),
#  ('south', 29672),
#  ('Scotland', 9569),
#  ('3.1%', 22),
#  ('Qaeda', 118),
#  ('torpex,', 2),
#  ('more', 108988),
#  ('personal', 13771),
#  ('Valance,', 19),
#  ('13.17', 5),
#  ('First', 23903),
#  ('School.', 9052),
#  ('Eightball', 35),
#  ('window', 2259),
#  ('allow', 9363),
#  ('(zero', 12),
#  ('digit', 326),
#  ('intermittent', 1135),
#  ('passed', 8627),
#  ('Washington', 18613),
#  ("Can't", 865),
#  ('SH1,', 1),
#  ('belt.', 234),
#  ('land', 20034),
#  ('Oluyemi', 3),
#  ('venue.', 760),
#  ('Stonewall', 285),
#  ('2013', 31894),
#  ('Foundation', 9435),
#  ('Zeni', 12),
#  ('another', 24062),
#  ('tables.', 185),
#  ('Miles', 2075),
#  ('Lai', 260),
#  ('29', 15746),
#  ('area.', 16061),
#  ('9,999', 7),
#  ('Plate', 617),
#  ('listed', 32026),
#  ('River', 43515),
#  ('28,', 11925),
#  ('Blank', 276),
#  ("Soilworker's", 1),
#  ('hypertext-based', 2),
#  ('Dollars', 80),
#  ('"1000', 22),
#  ('Boston', 9662),
#  ('Newmarket', 341),
#  ('Honey.', 53),
#  ('2014,', 17486),
#  ('ownership', 3625),
#  ('Everyone', 212),
#  ('23,', 12090),
#  ('satire', 767),
#  ('less)', 29),
#  ('Productions', 4314),
#  ('America', 21259),
#  ('Pictures.', 3845),
#  ('Collection', 2278),
#  ('Nintendo', 3867),
#  ('Tales', 1751),
#  ('pamphlet', 286),
#  ('Woodward', 517),
#  ('inner', 4250),
#  ('51', 1666),
#  ('matches', 13029),
#  ('Manson', 393),
#  ('sect,', 60),
#  ('(1997)', 416),
#  ('Khaled,', 42),
#  ('nationally', 3126),
#  ('manufactured', 6916),
#  ('(keyboards,', 120),
#  ('guitar,', 2810),
#  ('dage', 2),
#  ('Hughes', 2215),
#  ('Electronica', 64),
#  ('PolyGram', 111),
#  ('Gigabit', 80),
#  ('Edinburgh', 3435),
#  ('orchestra', 2389),
#  ('Negazione.', 6),
#  ('Key,', 203),
#  ('10,', 13790),
#  ('combined', 8356),
#  ('Vinton,', 40),
#  ('well,', 1979),
#  ('Salma', 112),
#  ('thousands', 3965),
#  ('list,', 1308),
#  ('added', 18991),
#  ('Rock', 12879),
#  ('jointly', 2239),
#  ('videos', 4389),
#  ('Bradbury.', 76),
#  ('Coalition', 1637),
#  ('Authority', 4537),
#  ('Mulagumoodu', 3),
#  ('control', 19883),
#  ('ignited', 170),
#  ('long', 25260),
#  ('Tulsa', 747),
#  ('grime', 184),
#  ('Moynihan,', 47),
#  ('Music.', 3316),
#  ('Squadron', 4537),
#  ('UK,', 4801),
#  ('project,', 2436),
#  ('time.', 16096),
#  ('Thieves,', 58),
#  ('eSports', 222),
#  ('Spring', 4306),
#  ('organization.', 4619),
#  ('Thousand', 759),
#  ('Aviation', 3073),
#  ('among', 33368),
#  ('words', 4701),
#  ('behind', 10525),
#  ('Herrera', 241),
#  ('Telecom', 552),
#  ('society.', 2762),
#  ('Federal', 12519),
#  ('Mitidika', 5),
#  ('101.7', 49),
#  ('sp.', 169),
#  ('Animated', 963),
#  ('vehicle', 6358),
#  ('Atlus', 116),
#  ('HQ', 264),
#  ('Problems', 252),
#  ('Pisces.', 133),
#  ('Israel', 4710),
#  ('Assault)', 12),
#  ('binary', 1389),
#  ('Inman', 150),
#  ('Bombo', 71),
#  ('plan,', 784),
#  ('reports,', 722),
#  ('78', 1096),
#  ('live-action', 924),
#  ('Accio', 1),
#  ('sound', 12183),
#  ('existence', 4418),
#  ('agricultural', 5656),
#  ('Worcestershire,', 502),
#  ('Blacksmithing', 3),
#  ('Nanaiah,', 1),
#  ('(film)', 76),
#  ('Dreifuss,', 6),
#  ('1034', 18),
#  ('society', 7873),
#  ('Sweden', 3577),
#  ('medal', 19043),
#  ('nearly', 10212),
#  ('C-130J', 21),
#  ('War,', 6139),
#  ('1792/1793', 1),
#  ('frequency', 2872),
#  ('size.', 1209),
#  ('104,793', 1),
#  ('west', 23279),
#  ('1048', 28),
#  ('pop,', 997),
#  ('past', 10120),
#  ('RM', 240),
#  ('transport,', 760),
#  ('communications', 4084),
#  ('Havilland', 345),
#  ('1966.', 3104),
#  ('sinks,', 28),
#  ('Meta,', 20),
#  ('low-power,', 31),
#  ('mill', 3767),
#  ('German,', 1166),
#  ('soldiers', 3927),
#  ('road', 19246),
#  ('Scotland.', 8966),
#  ('resistance.', 440),
#  ('frequency.', 313),
#  ('1,062', 12),
#  ('Naueti', 4),
#  ('Association.', 7035),
#  ('communities', 8876),
#  ('Valencia', 491),
#  ('Australia', 27852),
#  ('Bicol', 106),
#  ('modem.', 37),
#  ('sites.', 1390),
#  ('Monday', 2589),
#  ('0.20%', 3),
#  ('1919.', 1920),
#  ('briefly', 4917),
#  ('1942,', 1830),
#  ('Kenilworth', 140),
#  ('107.9', 69),
#  ('77', 1031),
#  ('country,', 4479),
#  ('scores.', 278),
#  ('Sussex', 2190),
#  ('solar', 3981),
#  ('system,', 7603),
#  ('skateboard', 188),
#  ('River,', 6889),
#  ('(Hawkeyes)', 1),
#  ('legislative', 5198),
#  ('branch', 10539),
#  ('Wright', 3307),
#  ('tied', 2565),
#  ('OID', 3),
#  ('Base.', 371),
#  ('109th', 155),
#  ('109,', 37),
#  ('creatorGryphon', 1),
#  ('tenth', 4334),
#  ('10%', 979),
#  ('married', 14234),
#  ('turn', 7677),
#  ('rowers', 105),
#  ('cases', 8547),
#  ('accept', 1881),
#  ('division.', 3240),
#  ('Jamaica.', 1080),
#  ('councils', 1292),
#  ('panchayat', 1793),
#  ('intersection', 4428),
#  ('supergroup', 701),
#  ('(IEEE),', 21),
#  ('partly', 3255),
#  ('Television', 9551),
#  ('Place', 3268),
#  ('Minor.', 194),
#  ('clips', 856),
#  ('contrasting', 415),
#  ('Tamil', 15726),
#  ('Atkinson', 518),
#  ('agriculture.', 756),
#  ('Bomber', 276),
#  ('Wells', 2339),
#  ('spent', 13878),
#  ('Dharamsala,', 12),
#  ('Barrier', 352),
#  ('Judy', 1267),
#  ('Greif', 41),
#  ('Mercury', 2185),
#  ('Perfect', 1077),
#  ('collecting', 1564),
#  ('III,', 1531),
#  ('SVT', 108),
#  ('primetime', 508),
#  ('squadron.', 243),
#  ('Wiener', 333),
#  ('Tampere', 153),
#  ('floors.', 440),
#  ('Brothers.', 860),
#  ("Nas'", 47),
#  ('Starrcade', 48),
#  ('pay-per-view', 1171),
#  ('Romance', 1040),
#  ('Fighting', 2267),
#  ('afternoon', 1043),
#  ('glow', 129),
#  ('Lateef', 79),
#  ('pesos', 71),
#  ('Blood,', 362),
#  ('Fame', 5808),
#  ('Minutes,', 79),
#  ('apple', 870),
#  ('traffic,', 488),
#  ('Carmine', 237),
#  ('(49', 41),
#  ('110', 1524),
#  ('1,1,1,2,2,3,3-Heptachloropropane', 1),
#  ('apaflurane', 1),
#  ('(HFC-245fa)', 1),
#  ('foam', 381),
#  ('Honeywell', 138),
#  ('operating', 15515),
#  ('Tribeca)', 1),
#  ('RZ,', 1),
#  ('Science', 16278),
#  ('applied', 8755),
#  ('1947;', 57),
#  ('brigade,', 106),
#  ('ambulance', 472),
#  ('Society.', 3667),
#  ('vapors', 59),
#  ('car', 13624),
#  ('facts', 810),
#  ('1980;', 66),
#  ('field', 25590),
#  ('2008.Crawford', 3),
#  ('11424', 2),
#  ('11425', 1),
#  ('1.15.1.5.2.,', 1),
#  ('violent', 2068),
#  ('aggressor', 32),
#  ('Dogday', 6),
#  ('Co.', 3202),
#  ('Illyria,', 10),
#  ('1.164.21', 1),
#  ('calendar)', 1105),
#  ('MA,', 215),
#  ("Hawaii's", 131),
#  ('Archeology', 710),
#  ('feedback', 1020),
#  ('overseas', 2415),
#  ('sunk', 1234),
#  ('Syria.', 661),
#  ('Peak', 1861),
#  ('Arthur.', 196),
#  ('Topeka,', 212),
#  ('compact', 2392),
#  ('118-foot', 1),
#  ('CA,', 308),
#  ('1992.', 7296),
#  ('1199:', 1),
#  ('bird', 7853),
#  ('engines.', 947),
#  ('Legislature,', 616),
#  ('1896,', 661),
#  ('#134.', 3),
#  ('giant', 3065),
#  ('organophosphorus', 39),
#  ('consoles,', 299),
#  ('boxers', 372),
#  ('Gardens,', 759),
#  ('visual', 7275),
#  ('Redcliffe', 111),
#  ('Commando', 692),
#  ('Braxton', 382),
#  ('Saran,', 23),
#  ('(11-DHC),', 1),
#  ('11-Dehydroprogesterone,', 1),
#  ('deoxycorticosterone,', 1),
#  ("Britain's", 1527),
#  ('Brigade,', 739),
#  ('Forces', 5132),
#  ('Avakian', 20),
#  ('Wayne', 5071),
#  ('Bryan', 2371),
#  ('bombings', 611),
#  ('killing', 3163),
#  ('likely', 7403),
#  ('two-act', 80),
#  ('21,', 12592),
#  ('recognizable', 847),
#  ('canes,', 15),
#  ('half.', 539),
#  ('Circus', 971),
#  ('14,000', 384),
#  ('citizens', 5192),
#  ('m.', 239),
#  ('Michaels,', 185),
#  ('Gramm,', 16),
#  ('Jon', 4329),
#  ('sheet', 1986),
#  ('Pacific,', 652),
#  ('Principality', 409),
#  ('Franz', 1235),
#  ('Senate,', 2252),
#  ('MLB', 1458),
#  ('musicians', 5643),
#  ('Esoteric,', 16),
#  ('Salamanders', 11),
#  ('(Anura).', 2),
#  ('Grampian', 153),
#  ('"seat",', 1),
#  ('(GTW)', 4),
#  ('Mogollan', 1),
#  ('122A', 4),
#  ('McLean', 688),
#  ('Arabesque', 52),
#  ('Roll', 1714),
#  ('Girlschool.', 7),
#  ('benzenetetrol', 1),
#  ('Bhagalpur', 92),
#  ('Rajendra', 523),
#  ('124.', 27),
#  ('VisiCalc', 15),
#  ('123rd', 91),
#  ('(=CCUG', 2),
#  ('eighty-six', 16),
#  ('automation', 845),
#  ('Batu', 268),
#  ('Ruthenia', 9),
#  ('bromine-substituted', 1),
#  ('1822.', 192),
#  ('Narjot', 6),
#  ('1936', 4151),
#  ('F1', 581),
#  ('Pitti', 33),
#  ('lawsuits', 456),
#  ('financial', 13676),
#  ('Alvis', 58),
#  ('Sanitation.', 9),
#  ('foot', 3252),
#  ('NoMad,', 3),
#  ('officinalis.', 19),
#  ('48-story', 5),
#  ('Pulse', 344),
#  ('Mohanbari', 5),
#  ('Deutsche', 1335),
#  ('Transportation,', 259),
#  ('Chhattisgarh', 431),
#  ('Purulia-Howrah', 2),
#  ('Digha', 29),
#  ('apparently', 2147),
#  ('MPPE', 3),
#  ('battle', 7415),
#  ('(3:56.73)', 1),
#  ('12995/12996', 1),
#  ('leagues', 2154),
#  ('1,2-alpha-mannosidase', 2),
#  ('Song', 5297),
#  ('personalities', 902),
#  ('Meriden,', 81),
#  ('Ep', 9),
#  ('Weiland.', 8),
#  ('12B', 14),
#  ('celebrities', 1230),
#  ('Comets', 284),
#  ('Lethbridge', 176),
#  ('crowned', 2504),
#  ('Anna', 3813),
#  ('1,2-Diazepine', 1),
#  ('1,2-Dimethyldiborane', 2),
#  ('1968)', 4141),
#  ('concerts', 2982),
#  ('"hopefuls"', 1),
#  ('Reims)', 10),
#  ('Hydrae', 18),
#  ('mortar', 397),
#  ('Securities', 1043),
#  ('neighbors', 750),
#  ('HBO', 1658),
#  ('nitrophenyl', 1),
#  ('Lotfy', 8),
#  ('robust', 759),
#  ('oil,', 881),
#  ('Amazon.', 192),
#  ('27,000', 139),
#  ('$42', 40),
#  ("City's", 1134),
#  ('taken,', 157),
#  ('holds', 12059),
#  ('Rods', 46),
#  ('(1)', 499),
#  ('F.C.', 2994),
#  ('Marsciano,', 3),
#  ('latest', 4014),
#  ('Kosice', 17),
#  ('Gotham', 419),
#  ('(12th', 69),
#  ('Marseille', 196),
#  ('1912.', 1250),
#  ('dissolved', 2854),
#  ('Tejano', 126),
#  ('Tooele', 65),
#  ('Counties,', 273),
#  ('under-12', 13),
#  ('Berlin', 3875),
#  ('Muddy', 254),
#  ('Waters,', 265),
#  ('12x12', 3),
#  ('Boozman', 8),
#  ('profession', 1169),
#  ('1963),', 240),
#  ('130-acre', 3),
#  ('Lemur', 18),
#  ('commuters,', 47),
#  ('13123', 1),
#  ('Bressack', 6),
#  ('blocks', 2633),
#  ('protocol.', 442),
#  ('basketball', 20878),
#  ('Gruenwald', 21),
#  ('works.', 2563),
#  ('ship', 15079),
#  ('Magoeba,', 2),
#  ('Grail', 116),
#  ('ANKS3,', 1),
#  ('135Xe', 3),
#  ('Seaview,', 4),
#  ('Hallston,', 1),
#  ('Mirboo', 14),
#  ('Balook', 1),
#  ('Shooter', 151),
#  ('ultimate', 1032),
#  ('Yuan', 413),
#  ('vied', 69),
#  ('Woodall,', 8),
#  ('trimethyluric', 1),
#  ('USCG', 71),
#  ('1.3.8', 1),
#  ('1391', 26),
#  ('scheme,', 413),
#  ('2227.', 1),
#  ('Dassin.', 20),
#  ('priestly', 110),
#  ('13cm', 1),
#  ('strictly', 1578),
#  ('detectable', 145),
#  ('sued', 837),
#  ('fields.', 1408),
#  ('Camacho', 78),
#  ('tautomers', 3),
#  ('1,3-Diketimines', 1),
#  ('solvent', 373),
#  ('ring-opened', 6),
#  ('Ira', 587),
#  ('Morrow,', 98),
#  ('fantasy', 7658),
#  ('half-hour', 964),
#  ('genre', 4065),
#  ('deal', 6409),
#  ('Elish', 6),
#  ('handful', 1273),
#  ('Envelopes', 2),
#  ('Prison.', 194),
#  ('Rockwell.', 46),
#  ('selected.', 276),
#  ('13-Sided', 1),
#  ('Dileptus', 6),
#  ('Reborn', 78),
#  ('Twenty20', 2063),
#  ('Eaters', 57),
#  ('Tumut', 38),
#  ('injunctions,', 9),
#  ('Studio', 3947),
#  ('Hoyt', 201),
#  ('Falls,', 1830),
#  ('equipage.', 1),
#  ('Nifelheim.', 5),
#  ('Sadbhawna', 2),
#  ('colonial', 4398),
#  ('MI5', 74),
#  ('owning', 461),
#  ('Art.', 1108),
#  ('Sqn', 29),
#  ('Stag.', 7),
#  ('thiocarbonyls', 1),
#  ('sulfur', 602),
#  ('YWHAB', 1),
#  ('V.', 4206),
#  ('AM/100.9', 1),
#  ('blessing', 208),
#  ('bi-level', 16),
#  ('Pontius', 53),
#  ('Kermanshah', 37),
#  ('anybody."', 2),
#  ('14A', 10),
#  ('cast.', 940),
#  ('525', 147),
#  ('shares.', 206),
#  ('reservations', 288),
#  ('Freleng', 64),
#  ('CFR', 101),
#  ('(Traditional)', 1),
#  ('Mutton,', 7),
#  ('Hells', 100),
#  ('review', 4890),
#  ('chlorinated', 71),
#  ('there.', 4616),
#  ('Harare;', 1),
#  ('bays', 705),
#  ('Aden,', 79),
#  ('Germans', 847),
#  ('immigrants,', 329),
#  ('1971),', 304),
#  ('Westerberg,', 12),
#  ('Rapides', 81),
#  ('LaSalle', 230),
#  ('(Vocals)', 7),
#  ('1861,', 644),
#  ('people.', 11341),
#  ('glass-fronted', 5),
#  ('online.', 1340),
#  ('Louisiana,', 2534),
#  ('politics,', 2335),
#  ('Nebraska', 2354),
#  ('Babur', 56),
#  ('favor)', 6),
#  ('Deathrock', 7),
#  ('closure', 2413),
#  ('Cardiff.', 303),
#  ('Train', 1359),
#  ('amongst', 4131),
#  ('Bashi.', 3),
#  ('Serbia.', 1679),
#  ('3:', 319),
#  ('Tudor', 1041),
#  ('Springs', 2900),
#  ('inserting', 236),
#  ('Jaynagar', 60),
#  ('(1563', 1),
#  ('1950', 4670),
#  ('1576', 53),
#  ('gymnasts', 153),
#  ('Artistic', 1286),
#  ('EB,', 7),
#  ('linesThe', 2),
#  ('fifth-lowest', 3),
#  ('choir.', 159),
#  ("Macias'", 2),
#  ('humanitarian', 1713),
#  ('Draco.', 46),
#  ('teenage', 1570),
#  ('15-like', 1),
#  ('TSM-235PC05', 1),
#  ('Program.', 1496),
#  ('burgh', 240),
#  ('governments,', 1761),
#  ('(early', 186),
#  ('crash,', 258),
#  ("players'", 276),
#  ('Australian-Pacific', 1),
#  ('Bessborough', 20),
#  ('year-old', 98),
#  ('oscillation', 102),
#  ('Wilcox', 402),
#  ('OG,', 6),
#  ('1632', 98),
#  ('Express/Mail', 3),
#  ('Flint.', 73),
#  ('ATKW)', 6),
#  ('screened', 2557),
#  ('Oval', 768),
#  ('Willem', 637),
#  ('Hole.', 72),
#  ('WE,', 3),
#  ('caste.', 168),
#  ('Serbia,', 454),
#  ('168th', 49),
#  ('setting.', 953),
#  ('intruder', 61),
#  ('androstenone,', 1),
#  ('$24,000),', 1),
#  ('Johnny', 5119),
#  ('rediscover', 41),
#  ('(synthon)', 1),
#  ('compounds.', 495),
#  ('constituency)', 1150),
#  ('facility.', 1276),
#  ('soloistic', 2),
#  ('(Grade', 55),
#  ('males', 1950),
#  ('hydroxyl', 187),
#  ('Mineral', 670),
#  ('Mission:', 107),
#  ('octagonal', 498),
#  ('Lithuania', 728),
#  ('Bozen', 9),
#  ('14-20).', 1),
#  ('(Oakland', 6),
#  ('brief', 4293),
#  ('friend.', 282),
#  ("San'a.", 8),
#  ('11-17-70),', 1),
#  ('Intercollegiate', 769),
#  ('(CIAA)', 13),
#  ('Haripriya', 12),
#  ('174-203.He', 1),
#  ('NA1,', 2),
#  ('UTC', 248),
#  ('(New', 926),
#  ('Group;', 80),
#  ('17683', 1),
#  ('(Code', 15),
#  ('Gagarin,', 20),
#  ('At', 38078),
#  ('speculative', 627),
#  ('multimedia', 1599),
#  ('81st', 263),
#  ('FJ61,', 1),
#  ('receptor', 3659),
#  ('radionuclide', 39),
#  ('Biesbroeck,', 2),
#  ('Kangxi', 297),
#  ('70.9', 3),
#  ('mansion', 1733),
#  ('moored', 166),
#  ('12:30', 53),
#  ('Dr', 2898),
#  ('Glencoe', 79),
#  ('impressive', 1025),
#  ("Kids'", 293),
#  ('Raw', 907),
#  ('functions.', 1145),
#  ('185', 338),
#  ('Christensen.', 71),
#  ('Friends.', 293),
#  ('mid', 3397),
#  ('improvement', 1764),
#  ('redefines', 12),
#  ("Luxury'.", 1),
#  ('recipients.', 128),
#  ('Pakhtakor', 34),
#  ('Wheels".', 5),
#  ('Annunciation', 142),
#  ('2009,', 16607),
#  ('House,1975)', 1),
#  ('SC-17', 3),
#  ('medicine.', 1246),
#  ('Archigram', 5),
#  ('1,800', 325),
#  ('garrisons', 93),
#  ('1808', 349),
#  ('1,808.Nearby', 1),
#  ('emission', 655),
#  ('Dio.', 45),
#  ('Mong.', 7),
#  ('indicates', 1973),
#  ('fission.', 31),
#  ('Amstrad', 458),
#  ('Palma', 376),
#  ('1931-1933', 2),
#  ('1,810', 2),
#  ('developments.', 308),
#  ('Rithun', 1),
#  ('Allwright.', 4),
#  ('States;', 432),
#  ('reception.', 327),
#  ('Hyattsville,', 19),
#  ('regularly', 5727),
#  ('Buckshot', 38),
#  ('photographic', 1282),
#  ('Conus,', 37),
#  ('direction', 5624),
#  ('1850', 932),
#  ('1852', 763),
#  ('TU1,', 2),
#  ('votes;', 61),
#  ('papers', 3090),
#  ('Giachetti.', 6),
#  ('Mart,', 53),
#  ('1875.', 535),
#  ('highway,', 247),
#  ('94th', 197),
#  ('Pot', 227),
#  ('96th', 249),
#  ('189.', 21),
#  ('Southampton', 1044),
#  ('Deacons', 112),
#  ('Camp', 4093),
#  ('happened', 3838),
#  ('blacksmith,', 50),
#  ('1893).It', 1),
#  ('Skating', 1700),
#  ('relevance.', 42),
#  ('beyond', 4485),
#  ('lace', 435),
#  ('Span.', 34),
#  ('page,', 441),
#  ('0.36%', 10),
#  ('(property', 9),
#  ('start.', 301),
#  ('Zutter', 8),
#  ('liter', 251),
#  ('Dale)', 12),
#  ('64.', 311),
#  ('reluctant', 328),
#  ('airlifted', 35),
#  ('Toms', 158),
#  ('technology', 14442),
#  ('brewed', 330),
#  ('Burgh,', 48),
#  ('trucking', 157),
#  ('duty', 2841),
#  ('slashed.', 5),
#  ('drive-time', 23),
#  ('Igbo', 331),
#  ('MP', 3479),
#  ('predates', 305),
#  ('1902.', 847),
#  ('Avadh', 12),
#  ('Vanderbilt,', 70),
#  ('Stetson', 160),
#  ('Budget', 698),
#  ('Anubis,', 14),
#  ('Schwindt.', 1),
#  ('1915:', 2),
#  ('controversial', 3956),
#  ('I.', 2448),
#  ('aviators', 82),
#  ('selectors.', 42),
#  ('Bonner.', 27),
#  ('Wildcats', 947),
#  ('20",', 3),
#  ('tree', 7901),
#  ('majors', 484),
#  ('Czechoslovakian', 96),
#  ('Minister,', 971),
#  ('Jane,', 167),
#  ('Jupiter,', 195),
#  ('1925).The', 1),
#  ('Lucerne.', 52),
#  ('factory', 3296),
#  ('seeking', 2805),
#  ('"burnt', 9),
#  ('17.3%', 6),
#  ('Rolls', 250),
#  ('Jaguar', 524),
#  ('restructured', 261),
#  ('Batis,', 1),
#  ('Suresnes.', 4),
#  ("Pat's", 47),
#  ('Argentina.', 2769),
#  ("A's", 243),
#  ('twenty-eighth', 118),
#  ('significantly,', 135),
#  ('clay', 2693),
#  ('Ouest-France', 69),
#  ('costumes', 643),
#  ('Log', 295),
#  ('titleholder', 813),
#  ('Alekhine.', 6),
#  ('Brockenhexen', 1),
#  ('Bremgarten', 29),
#  ('1938-1939', 11),
#  ('Rhodesian', 398),
#  ('Rice', 2081),
#  ('deadliest', 542),
#  ('recorded,', 641),
#  ('Anteros,', 1),
#  ('periodization', 23),
#  ('novels.', 1633),
#  ('USAFIP-NL,', 1),
#  ('Buildings', 645),
#  ('Remo', 152),
#  ('Autodromo', 101),
#  ('Sranan', 8),
#  ('Tongo.', 4),
#  ('Copenhagen,Denmark.', 1),
#  ('measure', 3809),
#  ('Saperstein,', 10),
#  ('1950)John', 1),
#  ('conduct', 2830),
#  ('Hyderabad', 1160),
#  ('Factory', 1522),
#  ('Hippodrome', 100),
#  ("League's", 1157),
#  ('punishable', 186),
#  ('Uber.', 23),
#  ('fugitives.', 24),
#  ('1958-59', 27),
#  ('Bratislava,', 109),
#  ('Ptychites.', 1),
#  ('Bulls', 1047),
#  ('sponsor', 1511),
#  ('Viking,', 57),
#  ('Pilita', 10),
#  ('literary,', 116),
#  ('laying', 709),
#  ('Clermont-Ferrand.', 8),
#  ('Again', 853),
#  ('1964By', 1),
#  ('nineteen', 1007),
#  ('Mediterranean', 3486),
#  ('Webfoots', 9),
#  ('two-door', 76),
#  ('1965,', 2378),
#  ('wagon),', 3),
#  ('Mokokchung_Town', 1),
#  ('Ervin.', 9),
#  ('Boulder', 589),
#  ('Headteacher', 90),
#  ('something', 2977),
#  ('Isstadion', 2),
#  ('1968,', 2844),
#  ('Datsun', 65),
#  ('predominated.', 10),
#  ('"Amstel', 39),
#  ('KFK', 71),
#  ('Steamboat', 191),
#  ('MGs,', 3),
#  ('Fulbright', 407),
#  ('Harelbeke', 78),
#  ('Pepsi-Cola', 34),
#  ('jazz-rock', 69),
#  ("'Hitler's", 2),
#  ('2000s:', 6),
#  ('Princess', 2983),
#  ('ANFC-organized', 8),
#  ('1971.Arsenal', 1),
#  ('Foro', 90),
#  ('Fiber', 284),
#  ('W.D.', 55),
#  ('Pakistan.', 5151),
#  ('Drug', 1627),
#  ('Gap,', 208),
#  ('Alla', 107),
#  ('redecoration', 14),
#  ('interchangeable', 330),
#  ('Perry', 2945),
#  ('Tests', 832),
#  ('1974-75', 48),
#  ('Nuggets.', 34),
#  ('consistently', 1653),
#  ('ReverbNation', 2),
#  ('dictator.', 27),
#  ('Pauley', 63),
#  ("Finland's", 192),
#  ('1976Not', 1),
#  ('370/135', 1),
#  ('Wars', 2818),
#  ('G.N.Dinesh', 1),
#  ('Me"', 1341),
#  ('(soccer),', 45),
#  ('254', 190),
#  ('furniture', 1418),
#  ('trends', 960),
#  ('1979)They', 1),
#  ('Merit.', 192),
#  ('Rico.', 1112),
#  ('congregation', 2347),
#  ('Eastbourne', 276),
#  ('Fraternidad', 9),
#  ('cost,', 389),
#  ('airfield', 898),
#  ('TK', 99),
#  ('Geilo,', 7),
#  ('(BFS),', 1),
#  ('(1850),', 14),
#  ('Athletics.', 569),
#  ('Representative', 3593),
#  ('Hamburger', 204),
#  ('League)', 287),
#  ('Grenelefe', 5),
#  ('Thirty-sixth', 8),
#  ('non-ranking', 46),
#  ('(two', 761),
#  ("NFL's", 386),
#  ('280i', 1),
#  ('LaPorte', 109),
#  ('runners-up', 724),
#  ('Parkfield', 14),
#  ('Ronald', 3450),
#  ('Harron', 18),
#  ('Carno', 16),
#  ('1985/86', 41),
#  ('struggled', 973),
#  ('knee', 1174),
#  ('Groove', 444),
#  ('rentals', 117),
#  ('400,000', 449),
#  ('60.4%.', 1),
#  ('WE84', 4),
#  ('Jailbreak,', 7),
#  ('Druaga.', 1),
#  ('programmers,', 81),
#  ('all-wheeled', 1),
#  ('Nabisco', 254),
#  ('full-bodied', 21),
#  ('metal.', 957),
#  ('Altadena,', 33),
#  ('Giavera', 7),
#  ('Moffat', 299),
#  ('pitcher', 2955),
#  ('Competition', 1799),
#  ('clubs,', 1407),
#  ('Turner.', 411),
#  ('Chemical', 2040),
#  ('painting.', 598),
#  ('Ricardo', 915),
#  ('Schenectady', 138),
#  ('1,028', 17),
#  ('Wagener', 27),
#  ('WITA', 5),
#  ('Delores,', 1),
#  ('one.', 2357),
#  ('Metz', 209),
#  ('Kristina', 246),
#  ('1989.New', 1),
#  ('Rohan', 232),
#  ('lesser', 1983),
#  ('muscle', 2635),
#  ('1990.', 6649),
#  ('sideline', 168),
#  ...]
